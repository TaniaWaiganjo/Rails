# %%
from google.colab import drive
drive.flush_and_unmount()
from google.colab import drive
drive.mount('/content/drive')
from unicodedata import numeric
from pathlib import Path
from google.colab import drive

import  pandas as pd
import re
# Out:
# Drive not mounted, so nothing to flush and unmount.
# Mounted at /content/drive

# %%
from unicodedata import numeric
from pathlib import Path

BASE_DIR=Path().resolve().parent
GDRIVE_MOUNT=BASE_DIR/"gdrive"
DATA_DIR = GDRIVE_MOUNT / "/gdrive/My Drive/Classification_MLs/Nomb_fsp_Backend_TPO_Accounts"
drive.mount(GDRIVE_MOUNT.as_posix(), force_remount=True)

# !ls /gdrive/MyDrive/Classification_MLs/Nomb_fsp_Backend_TPO_Accounts

tags = pd.read_excel(DATA_DIR/'Nomba_Accounts_Tags_Combined.xlsx')
# Out:
# Mounted at /gdrive
# Mapping_function.ipynb	Nomba_Accounts_Tags_Combined.xlsx  Nomba_Accounts_Tags.xlsx

# %%
# Create DataFrame
test_df = tags

# Mapping function
def map_investment(value):
    mapping_dict = dict(zip(test_df['reporting_tag'], test_df['mapping']))
    return mapping_dict.get(value, 'No mapping found')

# Apply the mapping function to the
test_df['mapped_value'] = test_df['reporting_tag'].apply(map_investment)


test_df
# Out:
#      account_id         reporting_tag     _col2              mapping  \
# 0             1               charges        26              charges
# 1             1  inter_bank_transfers         1  interbank_transfers
# 2             1                others        68               others
# 3             2          agent_refund        39         agent_refund
# 4             2           chargebacks       193          chargebacks
# ..          ...                   ...       ...                  ...
# 219         430                others      1193               others
# 220         430           withdrawals  43592895          withdrawals
# 221         463           withdrawals   2589412          withdrawals
# 222         661           withdrawals     28841          withdrawals
# 223         859           withdrawals     85031          withdrawals
#
#             mapped_value
# 0                charges
# 1    interbank_transfers
# 2                 others
# 3           agent_refund
# 4            chargebacks
# ..                   ...
# 219               others
# 220          withdrawals
# 221          withdrawals
# 222          withdrawals
# 223          withdrawals
#
# [224 rows x 5 columns]

# %%
# Get unique values from the 'mapping' column.
unique_values = test_df['mapping'].unique()

# Create a new DataFrame from the unique values.
unique_df = pd.DataFrame({'unique_mapping': unique_values})

# Print the DataFrame.
unique_df
# Out:
#           unique_mapping
# 0                charges
# 1    interbank_transfers
# 2                 others
# 3           agent_refund
# 4            chargebacks
# 5              transfers
# 6            withdrawals
# 7   fees_and_commissions
# 8      vendor_prefunding
# 9             stamp_duty
# 10          wallet_topup
# 11           bulk_amount
# 12         bill_payments
# 13                   isw
# 14                  upsl
# 15               loyalty
# 16            investment
# 17     terminal_purchase
# 18            settlement

# %%
import pickle

# Create a dictionary mapping 'reporting_tag' to 'mapped_value'.
mapping_dict = dict(zip(test_df['reporting_tag'], test_df['mapped_value']))

# Save the dictionary to a pickle file.
with open('mapping.pkl', 'wb') as f:
    pickle.dump(mapping_dict, f)

# %%
import pickle

# Load the dictionary from the pickle file.
with open('mapping.pkl', 'rb') as f:
    mapping_dict = pickle.load(f)

# Print the dictionary.
print(mapping_dict)
# Out:
# {'charges': 'charges', 'inter_bank_transfers': 'interbank_transfers', 'others': 'others', 'agent_refund': 'agent_refund', 'chargebacks': 'chargebacks', 'transfers': 'transfers', 'withdrawals': 'withdrawals', 'bank_fees': 'fees_and_commissions', 'interbank_transfers': 'interbank_transfers', 'inter bank transfer': 'interbank_transfers', 'vendor_prefunding': 'vendor_prefunding', 'stamp_duty': 'stamp_duty', 'wallet_topup': 'wallet_topup', 'bulk_amount': 'bulk_amount', 'commissions': 'fees_and_commissions', 'fees': 'fees_and_commissions', 'interbank_transactions': 'interbank_transfers', 'bill_payments': 'bill_payments', 'fees_and_commissions': 'fees_and_commissions', 'prefunding': 'vendor_prefunding', 'isw': 'isw', 'upsl': 'upsl', 'interbank_transaction': 'interbank_transfers', 'bank_charges_fees': 'fees_and_commissions', 'loyalty': 'loyalty', 'investment': 'investment', 'terminal_purchase': 'terminal_purchase', 'settlement': 'settlement', 'pay_by_transfer': 'transfers'}
